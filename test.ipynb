# %%
from tqdm import tqdm
import cv2
import sys
from Levenshtein import ratio
from glob import glob
import os

# %%
# sys.path.append('..')
from core.shared import CornerDetector, PerspectiveTransformer, GridCalculator, ChessPieceMapper, FENConverter, ImageGenerator

# %%
def compare_image_with_original(image_path):
    original_image = cv2.imread(image_path)
    corners = CornerDetector.detect_corners(original_image)
    transformed_image = PerspectiveTransformer.four_point_transform(image_path, corners)
    ptsT, ptsL = GridCalculator.plot_grid_on_transformed_image(transformed_image)
    detections, boxes = ChessPieceMapper.chess_pieces_detector(transformed_image)
    predicted_fen = FENConverter.generate_fen(ptsT, ptsL, detections, boxes)

    real_fen = "/".join(image_path.split("/")[-1].split(".")[0].split("-"))

    similarity = ratio(real_fen, predicted_fen)

    return similarity

# %%
test_images = glob("./tests/*.JPG", recursive=True)
len(test_images)
# Out:
# 499

# %%
# Out:
# {"id":"Jk23nmaRDOmM","time":1731686898,"expires":1731730098,"event":"message","topic":"training","title":"Model Traning","message":"100 Epochs are done 💪"}

# %%
results = []
for image in tqdm(test_images):
    try:
        results.append(compare_image_with_original(image))
    except Exception as e:
        print(e)
# Out:
#   1%|          | 6/499 [01:27<1:59:16, 14.52s/it]
# 'NoneType' object has no attribute 'sum'
#   2%|▏         | 11/499 [02:40<1:56:09, 14.28s/it]
# 'NoneType' object has no attribute 'sum'
#   4%|▍         | 21/499 [05:23<2:06:17, 15.85s/it]
# 'NoneType' object has no attribute 'sum'
#   5%|▍         | 24/499 [06:12<2:06:15, 15.95s/it]
# 'NoneType' object has no attribute 'sum'
#   7%|▋         | 37/499 [10:01<2:10:42, 16.97s/it]
# 'NoneType' object has no attribute 'sum'
#  10%|█         | 50/499 [13:58<2:19:17, 18.61s/it]
# 'NoneType' object has no attribute 'sum'
#  10%|█         | 52/499 [14:30<2:07:32, 17.12s/it]
# 'NoneType' object has no attribute 'sum'
#  14%|█▍        | 72/499 [20:39<1:58:15, 16.62s/it]
# 'NoneType' object has no attribute 'sum'
#  15%|█▍        | 73/499 [20:57<2:00:12, 16.93s/it]
# 'NoneType' object has no attribute 'sum'
#  15%|█▌        | 76/499 [21:43<1:49:56, 15.59s/it]
# 'NoneType' object has no attribute 'sum'
#  17%|█▋        | 86/499 [24:40<1:56:24, 16.91s/it]
# 'NoneType' object has no attribute 'sum'
#  18%|█▊        | 92/499 [26:24<1:53:14, 16.69s/it]
# 'NoneType' object has no attribute 'sum'
#  19%|█▉        | 97/499 [27:51<1:52:52, 16.85s/it]
# 'NoneType' object has no attribute 'sum'
#  21%|██        | 106/499 [30:24<1:50:38, 16.89s/it]
# max() arg is an empty sequence
#  25%|██▍       | 123/499 [35:16<1:43:50, 16.57s/it]
# 'NoneType' object has no attribute 'sum'
#  29%|██▉       | 145/499 [41:21<1:26:20, 14.63s/it]
# 'NoneType' object has no attribute 'sum'
#  29%|██▉       | 147/499 [41:46<1:20:29, 13.72s/it]
# 'NoneType' object has no attribute 'sum'
#  34%|███▎      | 168/499 [46:58<1:19:35, 14.43s/it]
# 'NoneType' object has no attribute 'sum'
#  34%|███▍      | 169/499 [47:11<1:17:00, 14.00s/it]
# 'NoneType' object has no attribute 'sum'
#  34%|███▍      | 170/499 [47:24<1:15:13, 13.72s/it]
# 'NoneType' object has no attribute 'sum'
#  35%|███▌      | 177/499 [49:04<1:16:47, 14.31s/it]
# max() arg is an empty sequence
#  37%|███▋      | 184/499 [50:39<1:12:19, 13.78s/it]
# 'NoneType' object has no attribute 'sum'
#  37%|███▋      | 187/499 [51:23<1:13:07, 14.06s/it]
# 'NoneType' object has no attribute 'sum'
#  40%|███▉      | 198/499 [54:04<1:12:54, 14.53s/it]
# 'NoneType' object has no attribute 'sum'
#  41%|████      | 205/499 [55:47<1:10:59, 14.49s/it]
# 'NoneType' object has no attribute 'sum'
#  42%|████▏     | 208/499 [56:31<1:09:46, 14.39s/it]
# 'NoneType' object has no attribute 'sum'
#  44%|████▎     | 218/499 [59:01<1:08:07, 14.55s/it]
# 'NoneType' object has no attribute 'sum'
#  44%|████▍     | 222/499 [59:57<1:04:12, 13.91s/it]
# 'NoneType' object has no attribute 'sum'
#  47%|████▋     | 236/499 [1:03:27<1:03:23, 14.46s/it]
# 'NoneType' object has no attribute 'sum'
#  49%|████▉     | 245/499 [1:05:41<1:00:34, 14.31s/it]
# 'NoneType' object has no attribute 'sum'
#  50%|████▉     | 248/499 [1:06:18<54:34, 13.04s/it]
# 'NoneType' object has no attribute 'sum'
#  54%|█████▎    | 268/499 [1:11:16<54:26, 14.14s/it]
# 'NoneType' object has no attribute 'sum'
#  54%|█████▍    | 269/499 [1:11:29<53:04, 13.84s/it]
# 'NoneType' object has no attribute 'sum'
#  58%|█████▊    | 289/499 [1:16:25<50:39, 14.47s/it]
# 'NoneType' object has no attribute 'sum'
#  59%|█████▊    | 292/499 [1:17:07<48:10, 13.96s/it]
# max() arg is an empty sequence
#  59%|█████▉    | 294/499 [1:17:32<45:21, 13.28s/it]
# 'NoneType' object has no attribute 'sum'
#  64%|██████▎   | 317/499 [1:23:03<40:38, 13.40s/it]
# 'NoneType' object has no attribute 'sum'
#  66%|██████▌   | 327/499 [1:25:25<40:45, 14.22s/it]
# 'NoneType' object has no attribute 'sum'
#  67%|██████▋   | 332/499 [1:26:35<38:23, 13.79s/it]
# 'NoneType' object has no attribute 'sum'
#  68%|██████▊   | 340/499 [1:28:36<39:17, 14.83s/it]
# max() arg is an empty sequence
#  69%|██████▉   | 344/499 [1:29:34<36:54, 14.29s/it]
# 'NoneType' object has no attribute 'sum'
#  72%|███████▏  | 361/499 [1:33:39<32:13, 14.01s/it]
# 'NoneType' object has no attribute 'sum'
#  73%|███████▎  | 366/499 [1:34:50<30:53, 13.94s/it]
# 'NoneType' object has no attribute 'sum'
#  77%|███████▋  | 385/499 [1:39:21<25:14, 13.29s/it]
# 'NoneType' object has no attribute 'sum'
#  79%|███████▉  | 393/499 [1:41:18<25:05, 14.21s/it]
# 'NoneType' object has no attribute 'sum'
#  81%|████████▏ | 406/499 [1:44:31<22:47, 14.71s/it]
# 'NoneType' object has no attribute 'sum'
#  91%|█████████ | 454/499 [1:56:25<10:49, 14.44s/it]
# 'NoneType' object has no attribute 'sum'
#  92%|█████████▏| 457/499 [1:57:07<09:48, 14.01s/it]
# 'NoneType' object has no attribute 'sum'
#  92%|█████████▏| 459/499 [1:57:35<09:09, 13.74s/it]
# max() arg is an empty sequence
#  95%|█████████▌| 475/499 [2:01:26<05:27, 13.63s/it]
# 'NoneType' object has no attribute 'sum'
#  99%|█████████▉| 494/499 [2:06:03<01:12, 14.44s/it]
# max() arg is an empty sequence
#  99%|█████████▉| 496/499 [2:06:28<00:40, 13.43s/it]
# 'NoneType' object has no attribute 'sum'
# 100%|██████████| 499/499 [2:07:13<00:00, 15.30s/it]

# %%
len(results)
# Out:
# {"id":"CIytw4Rm5Vhk","time":1731701188,"expires":1731744388,"event":"message","topic":"training","title":"Model Traning","message":"100 Epochs are done 💪"}

# %%
len(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(results)
#
# NameError: name 'results' is not defined
